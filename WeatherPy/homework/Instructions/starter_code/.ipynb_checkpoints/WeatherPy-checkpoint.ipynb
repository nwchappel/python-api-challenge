# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# 3 Observable Trends:
#
# 1. Max Temperature seems to decrease as the latitude either increases or decreases from the point of 0 Latitude,
# also known as the equator.
#
# 2. Humidity, wind speed, and cloudiness are not dependent on latitude.
#
# 3. There are far more colder Max Temperatures in the Northern Hemisphere than the Southern Hemisphere because it 
# is currently summer (12/06/2019) in the Southern Hemisphere.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=b05f5e20f9e2c655a402a37dfb85a157&units=imperial&q='

# %%
# Get weather data
weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
# Out:
# {'coord': {'lon': 147.06, 'lat': -42.78}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.51, 'pressure': 1003, 'humidity': 50, 'temp_min': 50, 'temp_max': 53.6}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 290}, 'clouds': {'all': 75}, 'dt': 1575664848, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1575656847, 'sunset': 1575711519}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# 'New Norfolk'

# %%
# set up lists to hold reponse info
city_name = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
lat = []
lng = []
country = []
date = []

record = 1

print("Beginning Data Retrieval")
print("------------------------")

for city in cities:
    try:
        weather_response = requests.get(query_url + city)
        weather_json = weather_response.json()
        city_name.append(weather_json["name"])
        max_temp.append(weather_json["main"]["temp_max"])
        humidity.append(weather_json["main"]["humidity"])
        cloudiness.append(weather_json["clouds"]["all"])
        wind_speed.append(weather_json["wind"]["speed"])
        lat.append(weather_json["coord"]["lat"])
        lng.append(weather_json["coord"]["lon"])
        country.append(weather_json["sys"]["country"])
        date.append(weather_json["dt"])
        city_record = weather_json["name"]
        
        print(f"Processing Record {record} | {city_record}")
        
        record = record + 1
        
    except:
        print("City not found. Skipping...")
    continue
    
print("------------------------")
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 | Mar del Plata
# Processing Record 2 | Port Alfred
# City not found. Skipping...
# Processing Record 3 | Vaini
# Processing Record 4 | Busselton
# Processing Record 5 | Adrar
# Processing Record 6 | Biabou
# Processing Record 7 | Buraydah
# Processing Record 8 | Sawtell
# Processing Record 9 | Garissa
# Processing Record 10 | Rusape
# Processing Record 11 | Harper
# Processing Record 12 | Beringovskiy
# Processing Record 13 | Marsa Matruh
# Processing Record 14 | Kruisfontein
# Processing Record 15 | Lagoa
# Processing Record 16 | Kapaa
# Processing Record 17 | Murchison
# Processing Record 18 | Rossland
# Processing Record 19 | Carnarvon
# Processing Record 20 | Abalak
# Processing Record 21 | Santo Domingo
# Processing Record 22 | Saldanha
# City not found. Skipping...
# Processing Record 23 | Nanyang
# Processing Record 24 | Snezhnogorsk
# Processing Record 25 | Ushuaia
# Processing Record 26 | Albany
# Processing Record 27 | Mataura
# Processing Record 28 | Hirado
# Processing Record 29 | Talnakh
# Processing Record 30 | Acapulco
# Processing Record 31 | Tuktoyaktuk
# Processing Record 32 | Victoria
# Processing Record 33 | Georgetown
# Processing Record 34 | Trairi
# Processing Record 35 | Hami
# Processing Record 36 | Mitu
# Processing Record 37 | Faanui
# Processing Record 38 | Esperance
# Processing Record 39 | Arraial do Cabo
# Processing Record 40 | Marabba
# Processing Record 41 | Ixtapa
# Processing Record 42 | Ambon
# Processing Record 43 | Bathsheba
# Processing Record 44 | Tokur
# Processing Record 45 | Qaanaaq
# Processing Record 46 | Mount Gambier
# Processing Record 47 | Chokurdakh
# City not found. Skipping...
# Processing Record 48 | Mecca
# Processing Record 49 | Cap Malheureux
# Processing Record 50 | New Norfolk
# Processing Record 51 | Lebu
# City not found. Skipping...
# Processing Record 52 | Punta Arenas
# Processing Record 53 | Alice Springs
# City not found. Skipping...
# Processing Record 54 | Ajaccio
# Processing Record 55 | Yulara
# Processing Record 56 | Tiksi
# Processing Record 57 | East London
# Processing Record 58 | Cherskiy
# Processing Record 59 | Avarua
# Processing Record 60 | Rikitea
# Processing Record 61 | Sobolevo
# City not found. Skipping...
# Processing Record 62 | Rawson
# Processing Record 63 | Atuona
# Processing Record 64 | Thompson
# Processing Record 65 | Norman Wells
# Processing Record 66 | Jamestown
# Processing Record 67 | Grindavik
# City not found. Skipping...
# Processing Record 68 | Hithadhoo
# Processing Record 69 | Tasiilaq
# Processing Record 70 | Omboue
# Processing Record 71 | Mahebourg
# Processing Record 72 | Mandalgovi
# Processing Record 73 | Silvania
# City not found. Skipping...
# Processing Record 74 | Homer
# Processing Record 75 | Duyun
# City not found. Skipping...
# Processing Record 76 | Hasaki
# Processing Record 77 | Nome
# Processing Record 78 | Hilo
# Processing Record 79 | Karratha
# Processing Record 80 | Vestmannaeyjar
# Processing Record 81 | Pangnirtung
# Processing Record 82 | Yellowknife
# Processing Record 83 | Hamilton
# Processing Record 84 | Bethel
# Processing Record 85 | Hermanus
# Processing Record 86 | Jiaozuo
# Processing Record 87 | Pokhara
# Processing Record 88 | Keetmanshoop
# Processing Record 89 | Guerrero Negro
# Processing Record 90 | Nelson Bay
# Processing Record 91 | Port Elizabeth
# Processing Record 92 | Saint-Philippe
# Processing Record 93 | Chuy
# Processing Record 94 | Shingu
# Processing Record 95 | Esmeraldas
# Processing Record 96 | Mananjary
# Processing Record 97 | Upernavik
# Processing Record 98 | Khatanga
# Processing Record 99 | Castro
# Processing Record 100 | Hovd
# Processing Record 101 | Geraldton
# Processing Record 102 | Broceni
# Processing Record 103 | Vestmanna
# Processing Record 104 | Okhotsk
# Processing Record 105 | Ketchikan
# City not found. Skipping...
# Processing Record 106 | Kaeo
# Processing Record 107 | Bluff
# Processing Record 108 | Lukoyanov
# Processing Record 109 | Saskylakh
# Processing Record 110 | Pisco
# Processing Record 111 | Tonneins
# Processing Record 112 | Lamar
# Processing Record 113 | Cockburn Town
# Processing Record 114 | Bandarbeyla
# Processing Record 115 | Tessalit
# Processing Record 116 | Barrow
# City not found. Skipping...
# Processing Record 117 | Oranjemund
# Processing Record 118 | Gaya
# Processing Record 119 | Lazaro Cardenas
# Processing Record 120 | Codrington
# Processing Record 121 | Lodja
# Processing Record 122 | Minab
# Processing Record 123 | Belmonte
# City not found. Skipping...
# Processing Record 124 | Donji Milanovac
# City not found. Skipping...
# Processing Record 125 | Yumen
# Processing Record 126 | La Ronge
# Processing Record 127 | Trelew
# Processing Record 128 | Egvekinot
# Processing Record 129 | Bangkal
# Processing Record 130 | Puerto Ayora
# Processing Record 131 | Kahului
# Processing Record 132 | Chapais
# Processing Record 133 | Elko
# Processing Record 134 | Lorengau
# Processing Record 135 | Ereymentau
# Processing Record 136 | San Quintin
# Processing Record 137 | Alofi
# Processing Record 138 | Arlit
# Processing Record 139 | Rambouillet
# Processing Record 140 | Biak
# Processing Record 141 | Saint-Joseph
# Processing Record 142 | Altona
# Processing Record 143 | Itaituba
# Processing Record 144 | Dukat
# Processing Record 145 | Cabo San Lucas
# Processing Record 146 | Obama
# Processing Record 147 | Cape Town
# Processing Record 148 | San Javier
# Processing Record 149 | Laguna
# Processing Record 150 | Hun
# Processing Record 151 | Baykit
# Processing Record 152 | Bredasdorp
# Processing Record 153 | Nieuw Amsterdam
# Processing Record 154 | Yurimaguas
# Processing Record 155 | Saint-Augustin
# City not found. Skipping...
# Processing Record 156 | Oyama
# Processing Record 157 | Barinas
# Processing Record 158 | Kaitangata
# City not found. Skipping...
# Processing Record 159 | Cascas
# Processing Record 160 | Douglas
# Processing Record 161 | Yongan
# Processing Record 162 | Muros
# Processing Record 163 | Pevek
# Processing Record 164 | Jiuquan
# Processing Record 165 | Smolenka
# Processing Record 166 | Hobart
# Processing Record 167 | Ludvika
# Processing Record 168 | Hofn
# Processing Record 169 | Provideniya
# Processing Record 170 | Komsomolskiy
# Processing Record 171 | Half Moon Bay
# Processing Record 172 | Dafeng
# Processing Record 173 | Port Macquarie
# Processing Record 174 | Poreba
# Processing Record 175 | Haines Junction
# Processing Record 176 | San Patricio
# Processing Record 177 | Zyryanka
# Processing Record 178 | Labuhan
# Processing Record 179 | Lowestoft
# City not found. Skipping...
# Processing Record 180 | Humaita
# Processing Record 181 | Beloha
# Processing Record 182 | Naze
# Processing Record 183 | Nantucket
# Processing Record 184 | Faya
# City not found. Skipping...
# Processing Record 185 | Ponta Delgada
# Processing Record 186 | Nikolskoye
# Processing Record 187 | Tuatapere
# Processing Record 188 | Agustin Codazzi
# City not found. Skipping...
# Processing Record 189 | Kawalu
# Processing Record 190 | Ilulissat
# Processing Record 191 | Severo-Kurilsk
# Processing Record 192 | Verkhnevilyuysk
# Processing Record 193 | Sao Filipe
# Processing Record 194 | Marawi
# Processing Record 195 | Pilar
# Processing Record 196 | Northam
# City not found. Skipping...
# Processing Record 197 | Les Cayes
# Processing Record 198 | Uglich
# Processing Record 199 | Nishihara
# Processing Record 200 | Changchun
# Processing Record 201 | Zvishavane
# Processing Record 202 | Port Blair
# Processing Record 203 | Ust-Omchug
# Processing Record 204 | Carballo
# Processing Record 205 | Noumea
# Processing Record 206 | Ormara
# Processing Record 207 | Fairbanks
# Processing Record 208 | Puerto Baquerizo Moreno
# Processing Record 209 | Veshenskaya
# Processing Record 210 | Touros
# Processing Record 211 | Ukiah
# Processing Record 212 | Hirara
# Processing Record 213 | Butaritari
# Processing Record 214 | Airai
# Processing Record 215 | Gotsu
# Processing Record 216 | Ostersund
# Processing Record 217 | Tura
# Processing Record 218 | Gravdal
# Processing Record 219 | Cidreira
# Processing Record 220 | Gaurnadi
# Processing Record 221 | Koumac
# Processing Record 222 | Matara
# Processing Record 223 | Ferme-Neuve
# Processing Record 224 | Sambava
# Processing Record 225 | Dharchula
# Processing Record 226 | Dunedin
# Processing Record 227 | Nicoya
# Processing Record 228 | Summerside
# Processing Record 229 | Dalbandin
# Processing Record 230 | Groa
# Processing Record 231 | Bakchar
# Processing Record 232 | Birao
# Processing Record 233 | Sorland
# Processing Record 234 | Salalah
# Processing Record 235 | Richards Bay
# Processing Record 236 | Nyurba
# Processing Record 237 | Kudahuvadhoo
# Processing Record 238 | Bambous Virieux
# Processing Record 239 | Fernley
# Processing Record 240 | Singaraja
# Processing Record 241 | Fortuna
# Processing Record 242 | Athabasca
# Processing Record 243 | Kingman
# City not found. Skipping...
# Processing Record 244 | Vung Tau
# Processing Record 245 | Salta
# Processing Record 246 | Dikson
# Processing Record 247 | Tiarei
# Processing Record 248 | Sarkand
# Processing Record 249 | Itacoatiara
# Processing Record 250 | Kedougou
# Processing Record 251 | Fort Nelson
# Processing Record 252 | Ribeira Grande
# City not found. Skipping...
# Processing Record 253 | Gamba
# Processing Record 254 | Rocha
# Processing Record 255 | Hobe Sound
# Processing Record 256 | Honiara
# Processing Record 257 | Kasangulu
# Processing Record 258 | Visby
# Processing Record 259 | Grand-Lahou
# Processing Record 260 | Gazojak
# Processing Record 261 | Nanortalik
# City not found. Skipping...
# Processing Record 262 | Seoul
# Processing Record 263 | Shelekhov
# Processing Record 264 | Livingstone
# Processing Record 265 | Dumai
# Processing Record 266 | Torbay
# Processing Record 267 | Caravelas
# City not found. Skipping...
# Processing Record 268 | Aklavik
# Processing Record 269 | Nalut
# Processing Record 270 | Skjervoy
# City not found. Skipping...
# Processing Record 271 | Acari
# City not found. Skipping...
# Processing Record 272 | Pandamatenga
# Processing Record 273 | Grand Gaube
# Processing Record 274 | Pingliang
# Processing Record 275 | Huarmey
# Processing Record 276 | Lavrentiya
# Processing Record 277 | Coos Bay
# Processing Record 278 | Lasa
# Processing Record 279 | Locri
# Processing Record 280 | Kavaratti
# Processing Record 281 | Belaya Gora
# Processing Record 282 | Longyearbyen
# City not found. Skipping...
# Processing Record 283 | Palmer
# Processing Record 284 | Launceston
# Processing Record 285 | Ashtian
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 286 | Smirnykh
# Processing Record 287 | San Cristobal
# Processing Record 288 | Srednekolymsk
# Processing Record 289 | Katherine
# Processing Record 290 | Sioux Lookout
# Processing Record 291 | Ayan
# Processing Record 292 | Yasnogorsk
# Processing Record 293 | Ouadda
# City not found. Skipping...
# Processing Record 294 | Nemuro
# Processing Record 295 | Aykhal
# Processing Record 296 | Elwood
# Processing Record 297 | Gigmoto
# Processing Record 298 | Okha
# Processing Record 299 | Merauke
# Processing Record 300 | Lovington
# Processing Record 301 | Nouadhibou
# Processing Record 302 | Kununurra
# Processing Record 303 | Tilichiki
# Processing Record 304 | Jacareacanga
# Processing Record 305 | Kodiak
# Processing Record 306 | Isangel
# Processing Record 307 | Bulawayo
# Processing Record 308 | Suileng
# Processing Record 309 | Bagdarin
# Processing Record 310 | Suez
# Processing Record 311 | Narsaq
# Processing Record 312 | Denpasar
# Processing Record 313 | Xining
# Processing Record 314 | Ancud
# Processing Record 315 | Portland
# Processing Record 316 | Vila Velha
# Processing Record 317 | Lewistown
# City not found. Skipping...
# Processing Record 318 | Leningradskiy
# Processing Record 319 | Midland
# Processing Record 320 | Flinders
# Processing Record 321 | Hue
# Processing Record 322 | Charters Towers
# Processing Record 323 | Meulaboh
# Processing Record 324 | Bemidji
# City not found. Skipping...
# Processing Record 325 | Rumonge
# Processing Record 326 | Mount Isa
# Processing Record 327 | Berdigestyakh
# Processing Record 328 | Hangu
# Processing Record 329 | Sangar
# Processing Record 330 | Madingou
# City not found. Skipping...
# Processing Record 331 | Road Town
# Processing Record 332 | Beya
# Processing Record 333 | Saint Anthony
# Processing Record 334 | Tuy Hoa
# Processing Record 335 | Atar
# Processing Record 336 | Kautokeino
# Processing Record 337 | North Platte
# Processing Record 338 | Zhuji
# Processing Record 339 | Thessalon
# Processing Record 340 | Puerto Escondido
# Processing Record 341 | Reconquista
# Processing Record 342 | Usinsk
# Processing Record 343 | Sulangan
# Processing Record 344 | Sosnovo-Ozerskoye
# City not found. Skipping...
# Processing Record 345 | Gbarnga
# Processing Record 346 | Lander
# Processing Record 347 | Dwarka
# Processing Record 348 | Yichang
# Processing Record 349 | Chon Buri
# Processing Record 350 | Auki
# Processing Record 351 | Neiafu
# Processing Record 352 | Cabedelo
# Processing Record 353 | Kidal
# Processing Record 354 | Morondava
# Processing Record 355 | Whitehorse
# Processing Record 356 | Goundam
# Processing Record 357 | Mogadishu
# Processing Record 358 | Buala
# Processing Record 359 | Alenquer
# Processing Record 360 | Amarante do Maranhao
# Processing Record 361 | Vologda
# Processing Record 362 | Bocas del Toro
# Processing Record 363 | Madang
# Processing Record 364 | Tautira
# Processing Record 365 | Poum
# Processing Record 366 | Port Hawkesbury
# City not found. Skipping...
# Processing Record 367 | Maragogi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 368 | Kiunga
# Processing Record 369 | Samdrup Jongkhar
# Processing Record 370 | Palaikastron
# Processing Record 371 | Cheremukhovo
# Processing Record 372 | Kieta
# Processing Record 373 | Parkes
# Processing Record 374 | Shimoda
# Processing Record 375 | Cabanas
# Processing Record 376 | Mahon
# Processing Record 377 | Bonthe
# Processing Record 378 | Wukari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 379 | Nouakchott
# Processing Record 380 | Mingoyo
# Processing Record 381 | Semnan
# Processing Record 382 | Safford
# Processing Record 383 | Souillac
# Processing Record 384 | Sao Joao da Barra
# Processing Record 385 | Klaksvik
# Processing Record 386 | Opuwo
# Processing Record 387 | Koutiala
# Processing Record 388 | Hambantota
# Processing Record 389 | Cairns
# Processing Record 390 | Samarai
# Processing Record 391 | Bull Savanna
# Processing Record 392 | Yamada
# Processing Record 393 | Arman
# Processing Record 394 | Ouallam
# Processing Record 395 | Oistins
# Processing Record 396 | Yazykovo
# Processing Record 397 | Novosergiyevka
# Processing Record 398 | Senanga
# Processing Record 399 | Hualmay
# Processing Record 400 | Korhogo
# Processing Record 401 | Quelimane
# City not found. Skipping...
# Processing Record 402 | Nanakuli
# Processing Record 403 | Genhe
# Processing Record 404 | Padang
# Processing Record 405 | Laguna de Duero
# Processing Record 406 | Byron Bay
# Processing Record 407 | Nan
# Processing Record 408 | Omsukchan
# Processing Record 409 | Male
# Processing Record 410 | Camacha
# Processing Record 411 | Swan Hill
# Processing Record 412 | Ambanja
# Processing Record 413 | Tazovskiy
# Processing Record 414 | Along
# Processing Record 415 | Gornoye Loo
# Processing Record 416 | Mamburao
# Processing Record 417 | Salvador
# City not found. Skipping...
# Processing Record 418 | Alibag
# Processing Record 419 | Sibolga
# Processing Record 420 | Chinameca
# Processing Record 421 | Alekseyevka
# Processing Record 422 | Beeville
# City not found. Skipping...
# Processing Record 423 | Sile
# Processing Record 424 | Eyl
# Processing Record 425 | Mabaruma
# Processing Record 426 | Madras
# Processing Record 427 | Balud
# Processing Record 428 | Pacific Grove
# Processing Record 429 | Baruun-Urt
# Processing Record 430 | Panaba
# Processing Record 431 | Carutapera
# Processing Record 432 | Brae
# Processing Record 433 | Channel-Port aux Basques
# City not found. Skipping...
# Processing Record 434 | Zhangye
# Processing Record 435 | Montelibano
# Processing Record 436 | Gasa
# Processing Record 437 | Ucluelet
# Processing Record 438 | Cove
# Processing Record 439 | Mehamn
# Processing Record 440 | Ayni
# Processing Record 441 | Beyneu
# Processing Record 442 | Tahe
# Processing Record 443 | Awbari
# Processing Record 444 | Paranaiba
# City not found. Skipping...
# Processing Record 445 | Kifri
# Processing Record 446 | Vanavara
# Processing Record 447 | Tucupita
# Processing Record 448 | Te Anau
# City not found. Skipping...
# Processing Record 449 | Fuerte Olimpo
# Processing Record 450 | Clyde River
# Processing Record 451 | Metu
# Processing Record 452 | Jalingo
# Processing Record 453 | Powell River
# City not found. Skipping...
# Processing Record 454 | Abu Samrah
# Processing Record 455 | Chanute
# Processing Record 456 | Katsuura
# Processing Record 457 | Vardo
# Processing Record 458 | Lapua
# Processing Record 459 | Mangan
# Processing Record 460 | Dasoguz
# City not found. Skipping...
# Processing Record 461 | Michalovce
# Processing Record 462 | Lyndon
# Processing Record 463 | Muzhi
# Processing Record 464 | Amahai
# Processing Record 465 | Tambacounda
# Processing Record 466 | San Francisco
# Processing Record 467 | Melo
# Processing Record 468 | Gladstone
# Processing Record 469 | Ngong
# Processing Record 470 | Hobyo
# Processing Record 471 | Bani Walid
# Processing Record 472 | Ostrovnoy
# Processing Record 473 | Roald
# Processing Record 474 | Aksay
# Processing Record 475 | Alanya
# City not found. Skipping...
# Processing Record 476 | Margate
# Processing Record 477 | Zelenogorskiy
# City not found. Skipping...
# Processing Record 478 | Waddan
# Processing Record 479 | Neuquen
# Processing Record 480 | Humberto de Campos
# Processing Record 481 | Ghanzi
# City not found. Skipping...
# Processing Record 482 | Lompoc
# Processing Record 483 | Ozinki
# Processing Record 484 | Kavieng
# Processing Record 485 | Pierre
# Processing Record 486 | Svetlaya
# Processing Record 487 | Yabrud
# Processing Record 488 | Liverpool
# City not found. Skipping...
# Processing Record 489 | San Jose
# City not found. Skipping...
# Processing Record 490 | Yalta
# Processing Record 491 | Barashevo
# Processing Record 492 | Wilmington
# Processing Record 493 | Tarakan
# Processing Record 494 | Matay
# Processing Record 495 | Prescott
# Processing Record 496 | Luanda
# Processing Record 497 | Cameta
# Processing Record 498 | Antalaha
# Processing Record 499 | Bilibino
# Processing Record 500 | Maniitsoq
# Processing Record 501 | Lebedinyy
# Processing Record 502 | Gizo
# Processing Record 503 | Tadepalle
# Processing Record 504 | Dingle
# Processing Record 505 | Cochabamba
# Processing Record 506 | Chase
# Processing Record 507 | Sunrise Manor
# Processing Record 508 | Solnechnyy
# Processing Record 509 | Port-Cartier
# Processing Record 510 | Askino
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 511 | Kachiry
# Processing Record 512 | Tamandare
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 513 | Agartala
# Processing Record 514 | San Pedro
# Processing Record 515 | Sinnamary
# Processing Record 516 | Kjollefjord
# Processing Record 517 | Havoysund
# City not found. Skipping...
# Processing Record 518 | Pitimbu
# Processing Record 519 | Rongcheng
# Processing Record 520 | Koroni
# City not found. Skipping...
# Processing Record 521 | Luwuk
# Processing Record 522 | Barrhead
# Processing Record 523 | Saquarema
# Processing Record 524 | Cartagena
# City not found. Skipping...
# Processing Record 525 | Saint George
# Processing Record 526 | Cody
# Processing Record 527 | Moron
# Processing Record 528 | Alta Floresta
# Processing Record 529 | Bose
# Processing Record 530 | San Policarpo
# Processing Record 531 | Hua Hin
# Processing Record 532 | Santa Maria
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 533 | Nirgua
# Processing Record 534 | Petropavlovsk-Kamchatskiy
# Processing Record 535 | Dudinka
# Processing Record 536 | Namatanai
# Processing Record 537 | Imuris
# City not found. Skipping...
# Processing Record 538 | Kargasok
# Processing Record 539 | Campina Verde
# Processing Record 540 | Diffa
# Processing Record 541 | Ust-Nera
# Processing Record 542 | Gorontalo
# Processing Record 543 | Sola
# Processing Record 544 | Daru
# Processing Record 545 | Honningsvag
# Processing Record 546 | Bodo
# City not found. Skipping...
# Processing Record 547 | Nauta
# Processing Record 548 | Plettenberg Bay
# Processing Record 549 | Ishigaki
# City not found. Skipping...
# Processing Record 550 | Fukue
# Processing Record 551 | Treinta y Tres
# Processing Record 552 | Teya
# Processing Record 553 | Constitucion
# Processing Record 554 | Pravdinskiy
# Processing Record 555 | Itarema
# City not found. Skipping...
# Processing Record 556 | Lubaczow
# City not found. Skipping...
# Processing Record 557 | Waipawa
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dictionary to use for DataFrame
weather_dict = {
    "City": city_name,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Lat": lat,
    "Lng": lng,
    "Country": country,
    "Date": date
}

# Create DataFrame from dictionary
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Lat           557
# Lng           557
# Country       557
# Date          557
# dtype: int64

# %%
# Export data to csv and display
weather_data.to_csv('output_data_file')
weather_data.head()
# Out:
#             City  Max Temp  Humidity  Cloudiness  Wind Speed    Lat     Lng  \
# 0  Mar del Plata     63.25        39          88        6.40 -46.43  -67.52
# 1    Port Alfred     70.00        88           0        5.99 -33.59   26.89
# 2          Vaini     65.84        86          21        9.71  15.34   74.49
# 3      Busselton     64.00        63          96        8.01 -33.64  115.35
# 4          Adrar     64.40        31         100        5.82  27.87   -0.29
#
#   Country        Date
# 0      AR  1575664856
# 1      ZA  1575664856
# 2      IN  1575664856
# 3      AU  1575664856
# 4      DZ  1575664856

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Convert Date to normal format
timestamp = 1575664856
date_time = datetime.fromtimestamp(timestamp)
date = date_time.strftime("%m/%d/%Y")

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create scatter plot and save as .png
weather_data.plot.scatter(x='Lat', y='Max Temp', edgecolors="black")
plt.title(f"City Latitude vs. Max Temperature ({date})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('lat_temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create scatter plot and save as .png
weather_data.plot.scatter(x='Lat', y='Humidity', edgecolors="black")
plt.title(f"Latitude vs. Humidity ({date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('lat_humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create scatter plot and save as .png
weather_data.plot.scatter(x='Lat', y='Cloudiness', edgecolors="black")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('lat_clouds.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create scatter plot and save as .png
weather_data.plot.scatter(x='Lat', y='Wind Speed', edgecolors="black")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('lat_wind.png')
